# %% [markdown]
# # Parsing the most horrible notebooks!
#
# This notebook will show you how you can parse some of the most horrible pdfs in existence.
# We will use the docling granite model. It has been published as part of the docling project and can be described as the "biggest gun" that you can use to parse the trickiest documents.
#
#
# ![Sample PDF](images/SCR-20251013-onxj.png)
#
#
# The docling projects offers a wide range of tools and aproaches to parse documents in a more eficient and scalable way
#
# **This is all running locally**

# %%
# all the imports
from pathlib import Path
from pdf2image import convert_from_path
from docling_core.types.doc import ImageRefMode
from docling_core.types.doc.document import DocTagsDocument, DoclingDocument
from mlx_vlm import load, stream_generate
from mlx_vlm.prompt_utils import apply_chat_template
from mlx_vlm.utils import load_config
from transformers.image_utils import load_image
from pathlib import Path
from PIL.Image import Image
from typing import Any

# %%
# Configuration
MODEL_PATH = "ibm-granite/granite-docling-258M-mlx"
SHOW_IN_BROWSER = True
#SAMPLE_PDF = "gnarly_pdfs/Apollo_guidance_and_navigation.pdf"
SAMPLE_PDF = "docling/gnarly_pdfs/apollo-11-flight-plan.pdf"
OUTPUT_PATH = "./output"

# %%
# Load model and processor
model, processor = load(path_or_hf_repo=MODEL_PATH)
config: dict[Any, Any] = load_config(model_path=MODEL_PATH)
# Out:
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]

# %%
# Convert PDF page to PNG and load as image
# This is the ultima ratio! If everything helps -> convert to image and feed straight to granite-docling
print("Converting PDF to PNG...")
images = convert_from_path(SAMPLE_PDF, dpi=200)
images = convert_from_path(pdf_path=SAMPLE_PDF, first_page=1, last_page=40, dpi=200)
# display(images[0])
# Out:
# Converting PDF to PNG...

# %%
# this is the default prompt for granite-docling. Feel free to change it!
PROMPT = "Convert this page to docling"
formatted_prompt = apply_chat_template(processor, config, PROMPT, num_images=1)

# %%
# THIS IS THE MAIN LOOP --> Generate DocTags output for all pages
# this is kind of ugly, because we manually iterate over the pages, but there was an with appending to the doctags object
print("Generating DocTags...\n")

for i, pil_image in enumerate(images):
    print(f"\nProcessing page {i+1}/{len(images)}...")
    
    # Generate DocTags for this page
    page_output = ""
    for token in stream_generate(
        model, processor, formatted_prompt, [pil_image], max_tokens=4096, verbose=False
    ):
        page_output += token.text
        if "</doctag>" in token.text:
            break
    
    # Create and save document for THIS page only
    doctags_doc = DocTagsDocument.from_doctags_and_image_pairs([page_output], [pil_image])
    doc = DoclingDocument.load_from_doctags(doctags_doc, document_name=f"Page {i+1}")
    
    # Save each page separately in a tmp folder within OUTPUT_PATH
    tmp_dir = Path(OUTPUT_PATH) / "tmp"
    tmp_dir.mkdir(parents=True, exist_ok=True)
    # HTML output
    tmp_output_path = tmp_dir / f"output_page_{i+1}.html"
    doc.save_as_html(tmp_output_path, image_mode=ImageRefMode.EMBEDDED)
    print(f"Page {i+1} saved to: {tmp_output_path}")
    # markdown output
    tmp_output_path = tmp_dir / f"output_page_{i+1}.md"
    doc.save_as_markdown(tmp_output_path)
    print(f"Page {i+1} saved to: {tmp_output_path}")
    # doctags output
    tmp_output_path = tmp_dir / f"output_page_{i+1}.json"
    doc.save_as_doctags(tmp_output_path)
    print(f"Page {i+1} saved to: {tmp_output_path}")

    # Print this page's markdown for debugging
    print(f"\nPage {i+1} Markdown:\n")
    print(doc.export_to_markdown())
    print("\n" + "="*50 + "\n")
# Out:
# Generating DocTags...
#
#
# Processing page 1/40...
# Page 1 saved to: output/tmp/output_page_1.html
# Page 1 saved to: output/tmp/output_page_1.md
# Page 1 saved to: output/tmp/output_page_1.json
#
# Page 1 Markdown:
#
# ## Apollo 11
#
# Flight Plan
#
# Final - July 1, 1969
#
# NATIONAL AERONAUTICS AND SPACE ADMINISTRATION
#
# MANNED SPACECRAFT CENTER HOUSTON, TEXAS
#
# ==================================================
#
#
# Processing page 2/40...
# Page 2 saved to: output/tmp/output_page_2.html
# Page 2 saved to: output/tmp/output_page_2.md
# Page 2 saved to: output/tmp/output_page_2.json
#
# Page 2 Markdown:
#
# Powered by TCPDF (www.tcpdf.org)
#
# ==================================================
#
#
# Processing page 3/40...
# Page 3 saved to: output/tmp/output_page_3.html
# Page 3 saved to: output/tmp/output_page_3.md
# Page 3 saved to: output/tmp/output_page_3.json
#
# Page 3 Markdown:
#
# APOLLO 11 - FLIGHT PLAN
#
# ==================================================
#
#
# Processing page 4/40...
# Page 4 saved to: output/tmp/output_page_4.html
# Page 4 saved to: output/tmp/output_page_4.md
# Page 4 saved to: output/tmp/output_page_4.json
#
# Page 4 Markdown:
#
# <!-- image -->
#
# ==================================================
#
#
# Processing page 5/40...
# Page 5 saved to: output/tmp/output_page_5.html
# Page 5 saved to: output/tmp/output_page_5.md
# Page 5 saved to: output/tmp/output_page_5.json
#
# Page 5 Markdown:
#
# NATIONAL AERONAUTICS AND SPACE ADMINISTRATION
#
# ## Apollo 11 Flight Plan
#
# Final - July 1, 1969
#
# MANNED SPACECRAFT CENTER
#
# HOUSTON, TEXAS
#
# ==================================================
#
#
# Processing page 6/40...
# Page 6 saved to: output/tmp/output_page_6.html
# Page 6 saved to: output/tmp/output_page_6.md
# Page 6 saved to: output/tmp/output_page_6.json
#
# Page 6 Markdown:
#
# ##
#
# ==================================================
#
#
# Processing page 7/40...
# Page 7 saved to: output/tmp/output_page_7.html
# Page 7 saved to: output/tmp/output_page_7.md
# Page 7 saved to: output/tmp/output_page_7.json
#
# Page 7 Markdown:
#
# L. J. Riché
#
# Flight Planning Branch
#
# Approved by:
#
# Concurrence:
#
# Director of Flight Operations
#
# Any comments or questions on this document should be forwarded to T. A. Guillory, Flight Planning Branch, mail code CF34, extension 427l.
#
# Any comments or questions on this document should be forwarded to T. A. Guillory, Flight Planning Branch, mail code CF34, extension 427l.
#
# ## APOLLO 11 APOLO AS-506/CSM-107/LM-5 FINAL FLIGHT PLAN
#
# JULY 1, 1969
#
# <!-- image -->
#
# <!-- image -->
#
# <!-- image -->
#
# <!-- image -->
#
# <!-- image -->
#
# <!-- image -->
#
# <!-- image -->
#
# ==================================================
#
#
# Processing page 8/40...
# Page 8 saved to: output/tmp/output_page_8.html
# Page 8 saved to: output/tmp/output_page_8.md
# Page 8 saved to: output/tmp/output_page_8.json
#
# Page 8 Markdown:
#
# ##
#
# ==================================================
#
#
# Processing page 9/40...
# Page 9 saved to: output/tmp/output_page_9.html
# Page 9 saved to: output/tmp/output_page_9.md
# Page 9 saved to: output/tmp/output_page_9.json
#
# Page 9 Markdown:
#
# ## ACKNOWLEDGMENT
#
# Acknowledgment is made to Messrs. Richard Rogers, William Killian and Spencer Gardner for their technical support in the preparation of the Apollo 11 Flight Plan.
#
# Views of the earth and the P52 stars shown in the Flight Plan were taken from the document, "Views from the CM and LM During the Flight of Apollo 11" (Mission G).
#
# The CSM and LM attitude information was taken from the document, "Lunar Orbit Attitude Sequence for Mission G".
#
# ==================================================
#
#
# Processing page 10/40...
# Page 10 saved to: output/tmp/output_page_10.html
# Page 10 saved to: output/tmp/output_page_10.md
# Page 10 saved to: output/tmp/output_page_10.json
#
# Page 10 Markdown:
#
# ##
#
# ==================================================
#
#
# Processing page 11/40...
# Page 11 saved to: output/tmp/output_page_11.html
# Page 11 saved to: output/tmp/output_page_11.md
# Page 11 saved to: output/tmp/output_page_11.json
#
# Page 11 Markdown:
#
# ## TABLE OF CONTENTS
#
# | Abbreviations                        | iii                             |
# |--------------------------------------|---------------------------------|
# | Introduction                         | x                               |
# | 1. Mission Description               | 1-1                             |
# | 2. Summary Flight Plan (TLC-TEC)     | 1-5                             |
# | 3. Summary Flight Plan (Lunar Orbit) | 1-6                             |
# | 4. LM Power Descent Profile          | 1-7                             |
# | 5. CSM Burn Schedule                 | 1-8                             |
# | 6. LM Burn Schedule                  | 1-9                             |
# | 7. Lunar Landing Site Data           | 1-10                            |
# | 8. Landmark Tracking Data            | 1-10                            |
# | 9. Flight Plan Notes                 | 1-13                            |
# | SECTION II - UPDATE FORMS            | SECTION II - UPDATE FORMS       |
# | 1. Update Forms Table                | 2-1                             |
# | 2. CSM Maneuver Update Pads          | 2-2                             |
# | 3. LM Maneuver Update Pads           | 2-27                            |
# | SECTION III - DETAILED TIMELINE      | SECTION III - DETAILED TIMELINE |
# | 1. Launch Phase                      | 3-1                             |
# | 2. TLI-T&D                           | 3-3, 3-4                        |
# | 3. Translunar Coast Activities       | 3-7, 3-17                       |
# | b. LM Familiarization                | 3-35                            |
# | c. Lunar Orbit Insertion             | 3-47                            |
# | 4. Lunar Orbit Activities            | 3-53                            |
# | a. Second LM Ingress                 | 3-63                            |
#
# ==================================================
#
#
# Processing page 12/40...
# Page 12 saved to: output/tmp/output_page_12.html
# Page 12 saved to: output/tmp/output_page_12.md
# Page 12 saved to: output/tmp/output_page_12.json
#
# Page 12 Markdown:
#
# ## SECTION III CONT'D
#
# | c. Undocking         | 3-67   |
# |----------------------|--------|
# | d. Touchdown         | 3-69   |
# | e. EVA               | 3-77   |
# | f. LM Liftoff        | 3-90   |
# | g. LM Active Docking | 3-94   |
# | h. LM Jettison       | 3-97   |
# | 5. TEI-TEC           | 3-101  |
# | 6. Entry             | 3-135  |
#
# ## SECTION IV DETAILED TEST OBJECTIVES
#
# | 1. Detailed Test Objectives                        | 4-1   |
# |----------------------------------------------------|-------|
# | 2. Test Objective/Mission Activity Cross Reference | 4-2   |
# | 3. Test Objectives                                 | 4-6   |
#
# ## SECTION V - CONSUMABLES
#
# | 1. RCS Propellant Usage   | 5-2   |
# |---------------------------|-------|
# | 2. SM RCS Budget          | 5-3   |
# | 3. CM RCS Budget          | 5-22  |
# | 4. SPS Budget             | 5-23  |
# | 5. LM RCS Budget          | 5-25  |
# | 6. DPS Budget             | 5-31  |
# | 7. APS Budget             | 5-32  |
# | 8. CSM EPS Budget         | 5-36  |
# | 9. LM EPS Budget          | 5-41  |
# | 10. LM ECS Budget         | 5-45  |
# | 11. PLSS Budget           | 5-50  |
#
# ## SECTION VI - SUMMARY FLIGHT PLAN
#
# Summary Flight Plan
#
# 6-1
#
# ==================================================
#
#
# Processing page 13/40...
# Page 13 saved to: output/tmp/output_page_13.html
# Page 13 saved to: output/tmp/output_page_13.md
# Page 13 saved to: output/tmp/output_page_13.json
#
# Page 13 Markdown:
#
# ## ABBREVIATIONS
#
# | ACCEL      | Accelerometer                                |
# |------------|----------------------------------------------|
# | ACN        | Ascension                                    |
# | ACT        | Activation                                   |
# | ACQ        | Acquisition                                  |
# | AEA        | Abort Electronics Assembly                   |
# | AGS        | Abort Guidance Subsystem                     |
# | AH         | Ampere Hours                                 |
# | ALSCC      | Apollo Lunar Surface Close-up Camera         |
# | ALT        | Altitude                                     |
# | AMP or amp | Ampere                                       |
# | ANG        | Antigua                                      |
# | ANT        | Antenna                                      |
# | AOH        | Apollo Operations Handbook                   |
# | AOS        | Acquisition of Signal or Acquisition of Site |
# | AOT        | Alignment Optical Telescope                  |
# | APS        | Ascent Propulsion Subsystem                  |
# | ARS        | Atmosphere Revitalization System             |
# | ATT        | Attitude                                     |
# | AUX        | Auxiliary                                    |
# | AZ         | Azimuth                                      |
# | BAT        | Battery                                      |
# | BDA        | Bermuda                                      |
# | Bio        | Bio-Medical Data on Voice Downlink           |
# | BP         | Barber Pole                                  |
# | BT         | Burn Time                                    |
# | BU         | Backup                                       |
# | BW         | Black & White                                |
# | BRKT       | Bracket                                      |
# | CAP COM    | Capsule Communicator                         |
# | CAL        | Calibration Angle                            |
# | CAM        | Camera                                       |
# | CB         | Circuit Breaker                              |
# | CDH        | Constant Delta Altitude                      |
# | CDR        | Commander                                    |
# | CDU        | Coupling Data Unit                           |
# | CEX        | Color External                               |
# | CIN        | Color Internal                               |
# | CIRC       | Circularization                              |
# | CK         | Check                                        |
# | CM         | Command Module                               |
# | CMC        | Command Module Computer                      |
# | CMD        | Command                                      |
# | CMP        | Command Module Pilot                         |
# | CNTL       | Control                                      |
# | C/O        | Check out                                    |
# | COAS       | Crew Optical Alignment Sight                 |
# | COMM       | Communications                               |
# | CONFIG     | Configuration                                |
# | CONT       | Continue                                     |
# | CP         | Control Point                                |
# | CRO        | Carnarvon, Australia                         |
# | CRYO       | Cryogenic                                    |
# | CSC        | Contingency Sample Collection                |
# | CSI        | Coelligiptic Sequence Initiation             |
# | CSM        | Command Service Module                       |
# | C&WS       | Caution and Warning System                   |
# | CYI        | Grand Canary Island                          |
# | DAP        | Digital Auto Pilot                           |
# | DB         | Deadband                                     |
# | DCA        | Digital Command Assembly                     |
# | DEDA       | Data Entry and Display Assembly              |
# | DEGS       | Degrees                                      |
# | DEPL       | Depletion                                    |
# | DET        | Digital Event Timer                          |
# | DIFF       | Difference                                   |
#
# ==================================================
#
#
# Processing page 14/40...
# Page 14 saved to: output/tmp/output_page_14.html
# Page 14 saved to: output/tmp/output_page_14.md
# Page 14 saved to: output/tmp/output_page_14.json
#
# Page 14 Markdown:
#
# DOI
#
# Descent Orbit Insertion
#
# DPS
#
# Descent Propulsion System
#
# DS
#
# Documented Sample
#
# DSE
#
# Data Storage Equipment
#
# DSKY
#
# Display and Keyboard
#
# DTO
#
# Detailed Test Objective
#
# DUA
#
# Digital Uplink Assembly
#
# DWN
#
# Down
#
# E
#
# Erasable or Enter
#
# EASEP
#
# Early Apollo Scientific Experiment Package
#
# ECS
#
# Environmental Control System
#
# ED
#
# Explosive Device
#
# EDT
#
# Eastern Daylight Time
#
# EFH
#
# Earth Far Horizon
#
# EI
#
# Earth (atmosphere) Interface
#
# EL
#
# Elevation or Electric
#
# EMS
#
# Entry Monitor System
#
# EMU
#
# Extravehicular Mobility Unit
#
# ENH
#
# Earth Near Horizon
#
# EPO
#
# Earth Parking Orbit
#
# EPS
#
# Electrical Power Subsystem
#
# EQUIP
#
# Equipment
#
# EST
#
# Eastern Standard Time
#
# EVA
#
# Extravehicular Activity
#
# EVAP
#
# Evaporator
#
# EVT
#
# Extravehicular Transfer
#
# EXT
#
# External
#
# f
#
# F Stop
#
# FC
#
# Fuel Cell
#
# FDAI
#
# Flight Director Attitude Indicator
#
# FLT
#
# Flight
#
# FM
#
# Frequency Modulated
#
# FOV
#
# Field of View
#
# fps or FPS
#
# Feed per second
#
# FT or ft
#
# Feed
#
# FTO
#
# Flight Test Objective
#
# FTP
#
# Full Throttle Position
#
# GBI
#
# Grand Bahama Islands
#
# GBM
#
# Grand Bahama (MSFN)
#
# GDC
#
# Gyro Display Coupler
#
# GDS
#
# Goldstone, California
#
# GET
#
# Ground Elapsed Time
#
# GETI
#
# Ground Elapsed Time of Ignition
#
# GLY
#
# Glycol
#
# GMT
#
# Greenwich Mean Time
#
# G&amp;N
#
# Guidance and Navigation
#
# GNCS
#
# Guidance Navigation Control System
#
# GWM
#
# Gum
#
# GYM
#
# Guaymas, Mexico
#
# H2
#
# Hydrogen
#
# HA
#
# Apogee Altitude
#
# HAW
#
# Hawaii
#
# HBR
#
# High Bit Rate (TLM)
#
# HD
#
# Highly Desirable
#
# HGA
#
# High Gain Antenna
#
# HI
#
# High
#
# Hp
#
# Pierce Altitude
#
# HSK
#
# Homeysuckle (Canberra, Australia)
#
# HTR
#
# Hater
#
# HTV
#
# USNS Huntsville
#
# ICDU
#
# Inertial Coupling Data Unit
#
# ID
#
# Identification
#
# IGA
#
# Inner Gimbal Angle
#
# IGN
#
# Ignition
#
# IMU
#
# Inertial Measurement Unit
#
# ==================================================
#
#
# Processing page 15/40...
# Page 15 saved to: output/tmp/output_page_15.html
# Page 15 saved to: output/tmp/output_page_15.md
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[6], line 34
#      32 # doctags output
#      33 tmp_output_path = tmp_dir / f"output_page_{i+1}.json"
# ---> 34 doc.save_as_doctags(tmp_output_path)
#      35 print(f"Page {i+1} saved to: {tmp_output_path}")
#      37 # Print this page's markdown for debugging
#
# File ~/Library/CloudStorage/OneDrive-IBM/01_CODE/galaxium-travels-infrastructure/docling/.venv/lib/python3.13/site-packages/docling_core/types/doc/document.py:5228, in DoclingDocument.save_as_doctags(self, filename, delim, from_element, to_element, labels, xsize, ysize, add_location, add_content, add_page_index, add_table_cell_location, add_table_cell_text, minified)
#    5226 if isinstance(filename, str):
#    5227     filename = Path(filename)
# -> 5228 out = self.export_to_doctags(
#    5229     delim=delim,
#    5230     from_element=from_element,
#    5231     to_element=to_element,
#    5232     labels=labels,
#    5233     xsize=xsize,
#    5234     ysize=ysize,
#    5235     add_location=add_location,
#    5236     add_content=add_content,
#    5237     add_page_index=add_page_index,
#    5238     # table specific flags
#    5239     add_table_cell_location=add_table_cell_location,
#    5240     add_table_cell_text=add_table_cell_text,
#    5241     minified=minified,
#    5242 )
#    5244 with open(filename, "w", encoding="utf-8") as fw:
#    5245     fw.write(out)
#
# File ~/Library/CloudStorage/OneDrive-IBM/01_CODE/galaxium-travels-infrastructure/docling/.venv/lib/python3.13/site-packages/docling_core/types/doc/document.py:5319, in DoclingDocument.export_to_doctags(self, delim, from_element, to_element, labels, xsize, ysize, add_location, add_content, add_page_index, add_table_cell_location, add_table_cell_text, minified, pages)
#    5295 my_labels = labels if labels is not None else DOCUMENT_TOKENS_EXPORT_LABELS
#    5296 serializer = DocTagsDocSerializer(
#    5297     doc=self,
#    5298     params=DocTagsParams(
#    (...)   5317     ),
#    5318 )
# -> 5319 ser_res = serializer.serialize()
#    5320 return ser_res.text
#
# File ~/Library/CloudStorage/OneDrive-IBM/01_CODE/galaxium-travels-infrastructure/docling/.venv/lib/python3.13/site-packages/docling_core/transforms/serializer/common.py:309, in DocSerializer.serialize(self, item, list_level, is_inline_scope, visited, **kwargs)
#     307 if self.doc.body.self_ref not in my_visited:
#     308     my_visited.add(self.doc.body.self_ref)
# --> 309     return self._serialize_body(**my_kwargs)
#     310 else:
#     311     return empty_res
#
# File ~/Library/CloudStorage/OneDrive-IBM/01_CODE/galaxium-travels-infrastructure/docling/.venv/lib/python3.13/site-packages/docling_core/transforms/serializer/common.py:288, in DocSerializer._serialize_body(self, **kwargs)
#     286 def _serialize_body(self, **kwargs) -> SerializationResult:
#     287     """Serialize the document body."""
# --> 288     subparts = self.get_parts(**kwargs)
#     289     res = self.serialize_doc(parts=subparts, **kwargs)
#     290     return res
#
# File ~/Library/CloudStorage/OneDrive-IBM/01_CODE/galaxium-travels-infrastructure/docling/.venv/lib/python3.13/site-packages/docling_core/transforms/serializer/common.py:429, in DocSerializer.get_parts(self, item, traverse_pictures, list_level, is_inline_scope, visited, **kwargs)
#     427 else:
#     428     my_visited.add(node.self_ref)
# --> 429 part = self.serialize(
#     430     item=node,
#     431     list_level=list_level,
#     432     is_inline_scope=is_inline_scope,
#     433     visited=my_visited,
#     434     **kwargs,
#     435 )
#     436 if part.text:
#     437     parts.append(part)
#
# File ~/Library/CloudStorage/OneDrive-IBM/01_CODE/galaxium-travels-infrastructure/docling/.venv/lib/python3.13/site-packages/docling_core/transforms/serializer/common.py:346, in DocSerializer.serialize(self, item, list_level, is_inline_scope, visited, **kwargs)
#     343         return empty_res
#     344     else:
#     345         part = (
# --> 346             self.text_serializer.serialize(
#     347                 item=item,
#     348                 doc_serializer=self,
#     349                 doc=self.doc,
#     350                 is_inline_scope=is_inline_scope,
#     351                 visited=my_visited,
#     352                 **my_kwargs,
#     353             )
#     354             if item.self_ref not in self.get_excluded_refs(**kwargs)
#     355             else empty_res
#     356         )
#     357 elif isinstance(item, TableItem):
#     358     part = self.table_serializer.serialize(
#     359         item=item,
#     360         doc_serializer=self,
#    (...)    363         **my_kwargs,
#     364     )
#
# File ~/Library/CloudStorage/OneDrive-IBM/01_CODE/galaxium-travels-infrastructure/docling/.venv/lib/python3.13/site-packages/docling_core/transforms/serializer/doctags.py:112, in DocTagsTextSerializer.serialize(self, item, doc_serializer, doc, visited, **kwargs)
#     109 parts: list[str] = []
#     111 if params.add_location:
# --> 112     location = item.get_location_tokens(
#     113         doc=doc,
#     114         xsize=params.xsize,
#     115         ysize=params.ysize,
#     116     )
#     117     if location:
#     118         parts.append(location)
#
# File ~/Library/CloudStorage/OneDrive-IBM/01_CODE/galaxium-travels-infrastructure/docling/.venv/lib/python3.13/site-packages/docling_core/types/doc/document.py:1117, in DocItem.get_location_tokens(self, doc, new_line, xsize, ysize)
#    1114 for prov in self.prov:
#    1115     page_w, page_h = doc.pages[prov.page_no].size.as_tuple()
# -> 1117     loc_str = DocumentToken.get_location(
#    1118         bbox=prov.bbox.to_top_left_origin(page_h).as_tuple(),
#    1119         page_w=page_w,
#    1120         page_h=page_h,
#    1121         xsize=xsize,
#    1122         ysize=ysize,
#    1123     )
#    1124     location += loc_str
#    1126 return location
#
# File ~/Library/CloudStorage/OneDrive-IBM/01_CODE/galaxium-travels-infrastructure/docling/.venv/lib/python3.13/site-packages/docling_core/types/doc/tokens.py:280, in DocumentToken.get_location(bbox, page_w, page_h, xsize, ysize)
#     271 @staticmethod
#     272 def get_location(
#     273     bbox: tuple[float, float, float, float],
#    (...)    277     ysize: int = 500,  # TODO review
#     278 ):
#     279     """Get the location string give bbox and page-dim."""
# --> 280     assert bbox[0] <= bbox[2], f"bbox[0]<=bbox[2] => {bbox[0]}<={bbox[2]}"
#     281     assert bbox[1] <= bbox[3], f"bbox[1]<=bbox[3] => {bbox[1]}<={bbox[3]}"
#     283     x0 = bbox[0] / page_w
#
# AssertionError: bbox[0]<=bbox[2] => 555.744<=443.27200000000005
